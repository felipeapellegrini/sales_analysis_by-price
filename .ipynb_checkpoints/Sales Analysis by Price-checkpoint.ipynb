# %% [markdown]
# ## Problem:
#
# A retail industry is trying to discover if reducing their sale price will result in a better sales volume (by inccreasing their sale conversion).
# They sent me a sheet with the produced quantity, sales quantity, sales volume and sales conversion percentage.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
producaoXvendas = pd.read_csv('producaoXvendas.csv', sep=';', encoding = "utf-8")
producaoXvendas.head(10)
# Out:
#         ref  pauta  custo  qtd_prd  qtd_fat  prc_giro    tot_fat  \
# 0  12091015   49.9  17.37       32       22  0.687500    1042.58
# 1  12601015   49.9  18.07      368      361  0.980978   17856.56
# 2  12602015   89.9  28.48      139      133  0.956835   11873.18
# 3  12603009  159.0  53.68      372      334  0.897849   51734.30
# 4  12605015  169.0  58.07      323       77  0.238390   11940.25
# 5  12606009  119.0  38.82      393      340  0.865140   39764.75
# 6  12607009  159.0  53.22      785      763  0.971975  118696.40
# 7  12609009  129.0  43.95      440      413  0.938636   52652.40
# 8  12611009  179.9  60.92      453      437  0.964680   77727.84
# 9  12612009  137.0  44.69     1116      979  0.877240  132714.72
#
#                    grupo  produto
# 0  MODINHA PARTE DE CIMA    BLUSA
# 1  MODINHA PARTE DE CIMA     BODY
# 2  MODINHA PARTE DE CIMA    BLUSA
# 3         COMPRIDO JEANS    FLARE
# 4  MODINHA PARTE DE CIMA  JAQUETA
# 5         COMPRIDO JEANS   SKINNY
# 6         COMPRIDO JEANS    FLARE
# 7         COMPRIDO JEANS   SKINNY
# 8         COMPRIDO JEANS    FLARE
# 9         COMPRIDO JEANS   SKINNY

# %%
producaoXvendas.describe()
# Out:
#                 ref        pauta        custo      qtd_prd      qtd_fat  \
# count  1.580000e+03  1580.000000  1580.000000  1580.000000  1580.000000
# mean   1.358695e+07   129.901076    41.319766   363.525949   308.745570
# std    5.651377e+05    34.888143    12.543342   310.300796   283.887732
# min    1.209102e+07    25.000000     0.000000     4.000000     3.000000
# 25%    1.312276e+07    99.900000    32.375000   152.000000   116.750000
# 50%    1.356551e+07   139.000000    42.065000   355.500000   279.000000
# 75%    1.407626e+07   149.000000    49.330000   480.000000   436.000000
# max    1.470501e+07   279.000000    95.230000  3800.000000  3317.000000
#
#           prc_giro        tot_fat
# count  1580.000000    1580.000000
# mean      0.825264   40975.014032
# std       0.206760   38150.689813
# min       0.030534     374.100000
# 25%       0.751562   12539.677500
# 50%       0.916361   35125.410000
# 75%       0.968471   62235.232500
# max       1.000000  382310.110000

# %%
producaoXvendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1580 entries, 0 to 1579
# Data columns (total 9 columns):
# ref         1580 non-null int64
# pauta       1580 non-null float64
# custo       1580 non-null float64
# qtd_prd     1580 non-null int64
# qtd_fat     1580 non-null int64
# prc_giro    1580 non-null float64
# tot_fat     1580 non-null float64
# grupo       1580 non-null object
# produto     1580 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 111.2+ KB

# %%
#checking the distribution of sales price
sns.distplot(producaoXvendas['pauta'], bins= 50)

# %%
#checking the distribution of produced volume per product.
sns.distplot(producaoXvendas['qtd_prd'], bins=50)

# %%
#checking the distribution of product cost.
sns.distplot(producaoXvendas['custo'], bins=50)

# %%
#checking the relationship between the produced and the sales conversion percentage.
sns.lmplot(x='qtd_prd', y='prc_giro', data=producaoXvendas)

# %%
#between the produced and volume sold.
sns.lmplot(x='qtd_prd', y='tot_fat', data=producaoXvendas)

# %%
#sale price vs sale conversion percentage.
sns.lmplot(x='pauta', y='prc_giro', data=producaoXvendas)

# %%
#sale price vs volume sold.
sns.lmplot(x='pauta', y='tot_fat', data=producaoXvendas)

# %%
#product cost vs volume sold.
sns.lmplot(x='custo', y='tot_fat', data=producaoXvendas)

# %%
#product cost vs sale conversion percentage.
sns.lmplot(x='custo', y='prc_giro', data=producaoXvendas)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
producaoXvendas.columns
# Out:
# Index(['ref', 'pauta', 'custo', 'qtd_prd', 'qtd_fat', 'prc_giro', 'tot_fat',
#        'grupo', 'produto'],
#       dtype='object')

# %%
#splitting data into train data and test data, referencing sales volume.
y = producaoXvendas['tot_fat']
X = producaoXvendas[['pauta', 'qtd_prd']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
lm = LinearRegression()

#fitting the linear model into training data and getting predictions
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#checking the error metrics.
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 8173.7603289357085
# MSE: 130399485.00641142
# RMSE: 11419.25938957564

# %%
#checking the leavings.
sns.distplot((y_test - predictions), bins=50)

# %%
#checking the correlation coefficents
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#          Coeffecient
# pauta     215.048420
# qtd_prd   107.482311

# %%
#splitting data into train data and test data, referencing sales conversion percentage.
y = producaoXvendas['prc_giro']
X = producaoXvendas[['pauta', 'qtd_prd']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
lm = LinearRegression()

#fitting the linear model into training data and getting predictions
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.16050874686577807
# MSE: 0.044036431585336454
# RMSE: 0.20984859204992645

# %%
sns.distplot((y_test - predictions), bins=50)

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#          Coeffecient
# pauta      -0.000005
# qtd_prd     0.000073

# %%
#splitting data into train data and test data, referencing sales conversion percentage and product cost.
y = producaoXvendas['prc_giro']
X = producaoXvendas[['custo', 'qtd_prd']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
lm = LinearRegression()

#fitting the linear model into training data and getting predictions
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#          Coeffecient
# custo      -0.000289
# qtd_prd     0.000074

# %% [markdown]
# ## Conclusions
#
# There isn't any linear relationship between the sale price and the sales conversion percentage or the sales ammount, but there is a relationship between the produced volume and the sales ammount.
# We decided to look to the product cost, considering that the most expensive product has a higher quality, but there wasn't any mathematical relation with the sale conversion percentage.
# I guess the company should consider increase volume produced per product.
